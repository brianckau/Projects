# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests as req
from edgar_operations import facts_df, time_series_comparison, annual_facts, quarterly_facts, all_quarterly_facts, time_series_comparison_v2
import warnings
warnings.filterwarnings('ignore')

# %%
headers = {"User-Agent":"abc@gmail.com"}
ticker = "MSFT"

# %% [markdown]
# Automatic Financial Statements Downloader

# %%
financial_data_df = facts_df(ticker)[0]

# %%
fiscal_year = 2025
fiscal_period = "FY"

# %% [markdown]
# Annual Financial Statements Data Fetching from SEC Edgar

# %%
annual_facts(ticker)
# Out:
# end                                                   2020-06-30  \
# fact
# Accounts Payable, Current                           1.253000e+10
# Accounts Receivable, after Allowance for Credit...  3.201100e+10
# Accounts Receivable, after Allowance for Credit...  2.700000e+09
# Accrued Income Taxes, Current                       2.130000e+09
# Accrued Income Taxes, Noncurrent                    2.943200e+10
# ...                                                          ...
# Unrecognized Tax Benefits, Increase Resulting f...  3.660000e+08
# Unrecognized Tax Benefits, Reduction Resulting ...  5.000000e+06
# Unrecognized Tax Benefits that Would Impact Eff...  1.210000e+10
# Weighted Average Number of Shares Outstanding, ...  7.683000e+09
# Weighted Average Number of Shares Outstanding, ...  7.610000e+09
#
# end                                                   2021-06-30  \
# fact
# Accounts Payable, Current                           1.516300e+10
# ...

# %% [markdown]
# Quarterly Financial Statements Data Fetching from SEC Edgar (Excl. Q4)

# %%
quarterly_facts(ticker)
# Out:
# end                                                   2019-09-30  \
# fact
# Accounts Payable, Current                           8.574000e+09
# Accounts Receivable, after Allowance for Credit...  1.908700e+10
# Accounts Receivable, after Allowance for Credit...  2.300000e+09
# Accrued Income Taxes, Current                       3.440000e+09
# Accrued Income Taxes, Noncurrent                    2.845700e+10
# ...                                                          ...
# Share-based Payment Arrangement, Noncash Expense    1.262000e+09
# Short-term Investments                              1.235190e+11
# Stockholders' Equity Attributable to Parent         1.060610e+11
# Weighted Average Number of Shares Outstanding, ...  7.710000e+09
# Weighted Average Number of Shares Outstanding, ...  7.634000e+09
#
# end                                                   2019-12-31  \
# fact
# Accounts Payable, Current                           8.811000e+09
# ...

# %% [markdown]
# Quarterly Financial Statements Data Fetching from SEC Edgar (Incl. Q4)

# %%
all_quarterly_facts(ticker)
# Out:
# end                                                   2019-09-30  \
# fact
# Accounts Payable, Current                           8.574000e+09
# Accounts Receivable, after Allowance for Credit...  1.908700e+10
# Accounts Receivable, after Allowance for Credit...  2.300000e+09
# Accrued Income Taxes, Current                       3.440000e+09
# Accrued Income Taxes, Noncurrent                    2.845700e+10
# ...                                                          ...
# Unrecognized Tax Benefits, Income Tax Penalties...           NaN
# Unrecognized Tax Benefits, Increase Resulting f...           NaN
# Unrecognized Tax Benefits, Increase Resulting f...           NaN
# Unrecognized Tax Benefits, Reduction Resulting ...           NaN
# Unrecognized Tax Benefits that Would Impact Eff...           NaN
#
# end                                                   2019-12-31  \
# fact
# Accounts Payable, Current                           8.811000e+09
# ...

# %% [markdown]
# Vertical Comparison of ONE LINE IN STATEMENTS

# %%
time_series_comparison_v2(all_quarterly_facts(ticker),["Accounts Payable, Current", "Accounts Receivable, after Allowance for Credit Loss, Current"])
